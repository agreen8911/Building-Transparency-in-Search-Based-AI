# %% [markdown]
# # Test for ML Final Project

# %%
# test multiple correspondence analysis
# think of it as PCA for categorical variables

pip install --user mca
# Out:
#   Cell In[1], line 4
#     pip install --user mca
#         ^
# SyntaxError: invalid syntax

# %%
# import libraries

import pandas as pd
import numpy as np
from mca import MCA 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# mca reference https://pypi.org/project/mca/

# %%
# read in data

df = pd.read_csv('llm_source_attribution_data.csv')

df_drop = df.drop(['Question','Attributed Sources','Number of Sources','Question Number', 'Notes While Testing', 'Model Version', 'Date', 'Ads Included in Response', 'Multi-modal Response'], axis=1)

display(df_drop)
# Out:
#         Question Category      LLM  Explicit Attribution  \
# 0       General Knowledge   gemini  explicit_attribution
# 1                 History   gemini  explicit_attribution
# 2           Entertainment   gemini  explicit_attribution
# 3                Politics   gemini  explicit_attribution
# 4           Entertainment   gemini  explicit_attribution
# ..                    ...      ...                   ...
# 595            Literature  chatGPT  explicit_attribution
# 596  Economics & Commerce  chatGPT  explicit_attribution
# 597               History  chatGPT  explicit_attribution
# 598         Entertainment  chatGPT  explicit_attribution
# 599              Politics  chatGPT  explicit_attribution
#
#     Are All Source Links Functional
# 0              all_links_functional
# 1              all_links_functional
# 2              all_links_functional
# 3              all_links_functional
# 4              all_links_functional
# ..                              ...
# 595            all_links_functional
# 596            all_links_functional
# 597            all_links_functional
# 598            all_links_functional
# 599            all_links_functional
#
# [600 rows x 4 columns]

# %%
# Ensure all categorical columns are of type 'category'
for col in df_drop.columns:
    df_drop[col] = df_drop[col].astype('category')
    
# Convert categorical variables (one-hot encoding)
data_hot = pd.get_dummies(df_drop, drop_first=True)

# %%
data_hot.head()
# Out:
#    Question Category_Entertainment  Question Category_Food & Cooking  \
# 0                            False                             False
# 1                            False                             False
# 2                             True                             False
# 3                            False                             False
# 4                             True                             False
#
#    Question Category_General Knowledge  Question Category_Geography  \
# 0                                 True                        False
# 1                                False                        False
# 2                                False                        False
# 3                                False                        False
# 4                                False                        False
#
#    Question Category_History  Question Category_Literature  \
# 0                      False                         False
# 1                       True                         False
# 2                      False                         False
# 3                      False                         False
# 4                      False                         False
#
#    Question Category_Philosophy  Question Category_Politics  \
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                        True
# 4                         False                       False
#
#    Question Category_Science & Technology  Question Category_Sports  \
# 0                                   False                     False
# 1                                   False                     False
# 2                                   False                     False
# 3                                   False                     False
# 4                                   False                     False
#
#    LLM_copilot  LLM_gemini  LLM_grok  LLM_llama  LLM_perplexity  \
# 0        False        True     False      False           False
# 1        False        True     False      False           False
# 2        False        True     False      False           False
# 3        False        True     False      False           False
# 4        False        True     False      False           False
#
#    Explicit Attribution_no_ads  Explicit Attribution_no_attribution  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
#
#    Are All Source Links Functional_no_links_functional  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Are All Source Links Functional_some_links_functional
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False

# %%
# Fit MCA on the data
mca_model = MCA(data_hot, ncols=data_hot.shape[1])

# %%
# Get the reduced space for rows (individuals) and columns (categories)
# rows = mca_model.fs_r
# cols = mca_model.fs_c

# Get the reduced space for rows (individuals) and columns (categories)
rows = mca_model.fs_r()  # Call the method to get row coordinates
cols = mca_model.fs_c()  # Call the method to get column coordinates

# %%
rows.shape, cols.shape
# Out:
# ((600, 13), (19, 13))

# %%
mca_result = MCA(data_hot)

# %%
# Plot the variables (categories) on the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(cols[0], cols[1])

# Ensure the labels correspond to the columns in the MCA result, not the dummy variables
category_labels = list(df_drop.columns)  # Use the original categorical column names

# Add labels for each category, but make sure you don’t exceed the number of categories in the MCA result
for i, label in enumerate(category_labels):
    if i < len(cols[0]):  # Make sure we do not go out of bounds
        plt.text(cols[0][i], cols[1][i], label, fontsize=9)

plt.xlabel("First Component")
plt.ylabel("Second Component")
plt.title("MCA - Categories (Variables) Plot")
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Plot the individuals (rows) on the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(rows[0], rows[1])

# Optionally, label the points with their row indices
for i, row in enumerate(rows.T):
    plt.text(row[0], row[1], str(i), fontsize=9)

plt.xlabel("First Component")
plt.ylabel("Second Component")
plt.title("MCA - Individuals (Rows) Plot")
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
