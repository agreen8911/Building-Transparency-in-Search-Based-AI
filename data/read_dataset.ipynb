# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_csv('llm_source_attribution_data.csv')

display(df)
# Out:
#      Question Number                                           Question  \
# 0                  1  "where does the saying keeping up with the jon...
# 1                  2       "when did day light savings start in the us"
# 2                  3             "what is the doll in the garden about"
# 3                  4    "where is a unitary system of government found"
# 4                  5            "who dies in season 2 of the originals"
# ..               ...                                                ...
# 595               96    "who is the author of the book arabian nights?"
# 596               97              "who is the voice of tony the tiger?"
# 597               98       "who lives in the imperial palace in tokyo?"
# 598               99           "who played will on as the world turns?"
# 599              100     "who won the election for mayor of cleveland?"
#
#     Notes While Testing     Question Category      LLM        Model Version  \
# 0                   NaN     General Knowledge   gemini       gemini_1.5_pro
# 1                   NaN               History   gemini       gemini_1.5_pro
# 2                   NaN         Entertainment   gemini       gemini_1.5_pro
# 3                   NaN              Politics   gemini       gemini_1.5_pro
# 4                   NaN         Entertainment   gemini       gemini_1.5_pro
# ..                  ...                   ...      ...                  ...
# 595                 NaN            Literature  chatGPT  chatgpt_with_search
# 596                 NaN  Economics & Commerce  chatGPT  chatgpt_with_search
# 597                 NaN               History  chatGPT  chatgpt_with_search
# 598                 NaN         Entertainment  chatGPT  chatgpt_with_search
# 599                 NaN              Politics  chatGPT  chatgpt_with_search
#
#      Explicit Attribution     Date  \
# 0    explicit_attribution  11/2/24
# 1    explicit_attribution  11/2/24
# 2    explicit_attribution  11/2/24
# 3    explicit_attribution  11/2/24
# 4    explicit_attribution  11/2/24
# ..                    ...      ...
# 595  explicit_attribution  11/4/24
# 596  explicit_attribution  11/4/24
# 597  explicit_attribution  11/4/24
# 598  explicit_attribution  11/4/24
# 599  explicit_attribution  11/4/24
#
#                                     Attributed Sources  Number of Sources  \
# 0    "www.commonlit.org, www.history.howstuffworks....                2.0
# 1                                  "www.wikipedia.org"                1.0
# 2    "www.goodreads.com, amazon.com, www.publishers...                3.0
# 3    "www.britannica.com, www.guides.skylinecollege...                3.0
# 4                                  "www.wikipedia.org"                1.0
# ..                                                 ...                ...
# 595  "www.newworldencyclopedia.org, www.britannica....               10.0
# 596  "people.com, www.omahamagazine.com, en.wikiped...                9.0
# 597  "sankan.kunaicho.go.jp, www.japanmanifest.com,...               11.0
# 598  "en.wikipedia.org, www.looper.com, www.soapcen...                6.0
# 599  "www.news5cleveland.com, liveresults.boe.ohio....                6.0
#
#     Are All Source Links Functional Ads Included in Response  \
# 0              all_links_functional                   no_ads
# 1              all_links_functional                   no_ads
# 2              all_links_functional                   no_ads
# 3              all_links_functional                   no_ads
# 4              all_links_functional                   no_ads
# ..                              ...                      ...
# 595            all_links_functional                   no_ads
# 596            all_links_functional                   no_ads
# 597            all_links_functional                   no_ads
# 598            all_links_functional                   no_ads
# 599            all_links_functional                   no_ads
#
#     Multi-modal Response
# 0              text_only
# 1              text_only
# 2              text_only
# 3              text_only
# 4              text_only
# ..                   ...
# 595            text_only
# 596            text_only
# 597            text_only
# 598            text_only
# 599            text_only
#
# [600 rows x 13 columns]

# %%
df = df.drop(columns=['Question Number', 'Notes While Testing'])
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)  
df['Ads Included in Response'] = df['Ads Included in Response'].replace({'no_ads': False, 'ads': True})
df.columns = df.columns.str.strip()
df['Attributed Sources'] = df['Attributed Sources'].str.replace('"', '')

display(df)
# Out:
# /var/folders/y4/mzcnvkgn2mn06pm9k145blz80000gn/T/ipykernel_69275/328125749.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
# /var/folders/y4/mzcnvkgn2mn06pm9k145blz80000gn/T/ipykernel_69275/328125749.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
#                                               Question     Question Category  \
# 0    "where does the saying keeping up with the jon...     General Knowledge
# 1         "when did day light savings start in the us"               History
# 2               "what is the doll in the garden about"         Entertainment
# 3      "where is a unitary system of government found"              Politics
# 4              "who dies in season 2 of the originals"         Entertainment
# ..                                                 ...                   ...
# 595    "who is the author of the book arabian nights?"            Literature
# 596              "who is the voice of tony the tiger?"  Economics & Commerce
# 597       "who lives in the imperial palace in tokyo?"               History
# 598           "who played will on as the world turns?"         Entertainment
# 599     "who won the election for mayor of cleveland?"              Politics
#
#          LLM        Model Version  Explicit Attribution       Date  \
# 0     gemini       gemini_1.5_pro  explicit_attribution 2024-11-02
# 1     gemini       gemini_1.5_pro  explicit_attribution 2024-11-02
# 2     gemini       gemini_1.5_pro  explicit_attribution 2024-11-02
# 3     gemini       gemini_1.5_pro  explicit_attribution 2024-11-02
# 4     gemini       gemini_1.5_pro  explicit_attribution 2024-11-02
# ..       ...                  ...                   ...        ...
# 595  chatGPT  chatgpt_with_search  explicit_attribution 2024-11-04
# 596  chatGPT  chatgpt_with_search  explicit_attribution 2024-11-04
# 597  chatGPT  chatgpt_with_search  explicit_attribution 2024-11-04
# 598  chatGPT  chatgpt_with_search  explicit_attribution 2024-11-04
# 599  chatGPT  chatgpt_with_search  explicit_attribution 2024-11-04
#
#                                     Attributed Sources  Number of Sources  \
# 0     www.commonlit.org, www.history.howstuffworks.com                2.0
# 1                                    www.wikipedia.org                1.0
# 2    www.goodreads.com, amazon.com, www.publishersw...                3.0
# 3    www.britannica.com, www.guides.skylinecollege....                3.0
# 4                                    www.wikipedia.org                1.0
# ..                                                 ...                ...
# 595  www.newworldencyclopedia.org, www.britannica.c...               10.0
# 596  people.com, www.omahamagazine.com, en.wikipedi...                9.0
# 597  sankan.kunaicho.go.jp, www.japanmanifest.com, ...               11.0
# 598  en.wikipedia.org, www.looper.com, www.soapcent...                6.0
# 599  www.news5cleveland.com, liveresults.boe.ohio.g...                6.0
#
#     Are All Source Links Functional Ads Included in Response  \
# 0              all_links_functional                    False
# 1              all_links_functional                    False
# 2              all_links_functional                    False
# 3              all_links_functional                    False
# 4              all_links_functional                    False
# ..                              ...                      ...
# 595            all_links_functional                    False
# 596            all_links_functional                    False
# 597            all_links_functional                    False
# 598            all_links_functional                    False
# 599            all_links_functional                    False
#
#     Multi-modal Response
# 0              text_only
# 1              text_only
# 2              text_only
# 3              text_only
# 4              text_only
# ..                   ...
# 595            text_only
# 596            text_only
# 597            text_only
# 598            text_only
# 599            text_only
#
# [600 rows x 11 columns]
